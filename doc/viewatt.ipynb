# %%
import numpy as np
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt
import matplotlib.font_manager as fm
fm.fontManager.addfont('/usr/share/fonts/truetype/times.ttf')
plt.rc('font',family='Times New Roman')

# %%
attention_matrix = np.array([
    [0.33,0.11,0.43,0.86],
    [0.32,0.14,0.41,0.81],
    [0.33,0.18,0.46,0.87],
    [0.37,0.12,0.43,0.81],
    [0.31,0.22,0.47,0.84],
    [0.32,0.23,0.42,0.83],
    [0.23,0.28,0.46,0.87],
    [0.27,0.32,0.53,0.71],
    [0.11,0.32,0.67,0.64],
    [0.12,0.33,0.72,0.33],
])

# 绘图
plt.rcParams.update({'font.size': 14})
plt.figure(figsize=(6, 6),dpi=300)
sns.heatmap(attention_matrix, annot=False, cmap="YlGnBu",
            xticklabels=["E","B","S","G"],
            yticklabels=["5000","4000", "3000","2000","1500", "1000","750", "500","250", "100"])
plt.title("Attention Weights Across Views")
plt.xlabel("View")
plt.ylabel("Sample Categories (Protein Length)")

plt.tight_layout()
plt.savefig("SampleViewAtt.svg")
plt.savefig("SampleViewAtt.jpg")
plt.show()
